# %%
import nltk
nltk.data.path.clear()
nltk.data.path.append('/Users/girivasanth/nltk_data')

# %%
import re
import nltk
from nltk.corpus import brown, stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# ✅ Set NLTK data path (IMPORTANT)
nltk.data.path.append('/Users/girivasanth/nltk_data')

# Tools
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# Load Brown corpus
text = " ".join(brown.words()[:2000])

# Normalization
text = text.lower()
text = re.sub(r'[^a-z\s]', '', text)

# ✅ Tokenization (offline-safe)
tokens = text.split()

# Stopword Removal
tokens = [t for t in tokens if t not in stop_words]

# Stemming
stemmed = [stemmer.stem(t) for t in tokens]

# Lemmatization
lemmatized = [lemmatizer.lemmatize(t) for t in tokens]

# Output
print("Brown Tokens:", tokens[:20])
print("Brown Stemmed:", stemmed[:20])
print("Brown Lemmatized:", lemmatized[:20])
# Out:
# Brown Tokens: ['fulton', 'county', 'grand', 'jury', 'said', 'friday', 'investigation', 'atlantas', 'recent', 'primary', 'election', 'produced', 'evidence', 'irregularities', 'took', 'place', 'jury', 'said', 'termend', 'presentments']
# Brown Stemmed: ['fulton', 'counti', 'grand', 'juri', 'said', 'friday', 'investig', 'atlanta', 'recent', 'primari', 'elect', 'produc', 'evid', 'irregular', 'took', 'place', 'juri', 'said', 'termend', 'present']
# Brown Lemmatized: ['fulton', 'county', 'grand', 'jury', 'said', 'friday', 'investigation', 'atlanta', 'recent', 'primary', 'election', 'produced', 'evidence', 'irregularity', 'took', 'place', 'jury', 'said', 'termend', 'presentment']
